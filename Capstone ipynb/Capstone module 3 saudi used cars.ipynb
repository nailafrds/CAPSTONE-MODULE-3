# %% [markdown]
# # **Capstone Module 3 : Saudi Arabia Used Cars**

# %% [markdown]
# [Sumber data Saudi Arabia Used Cars](https://www.kaggle.com/datasets/raihanmuhith/saudi-arabia-used-car)
#
# ## **Contents**
#
# 1. Business Problem Understanding
# 2. Data Understanding
# 3. Data Preprocessing
# 4. Modeling
# 5. Conclusion
# 6. Recommendation
#
# ****

# %% [markdown]
# ## **1. Business Problem Understanding**

# %% [markdown]
# ### **Context**
#
#
# Mobil merupakan sarana transportasi manusia, seiring perkembangan zaman manusia semakin membutuhkan adanya mobil untuk berkegiatan sehari-hari, namun rata rata harga mobil saat ini terbilang cukup tinggi sehingga banyak orang lebih memilih membeli mobil bekas dariapada membeli mobil baru untuk di gunakan sehari-hari.
#
# Saudi Arabia sebagai salah satu negara yang menyediakan market jual beli mobil bekas dengan jumlah yang cukup tinggi. Segemntasi marketnya pun terbagi bagi:
# 1. Berdasarkan jenis kendaraan (SUV,MPV,sedan dan hattback)
# 2. Berdasarkan penjualan (online dan offline)
#
# Di landir dari laman `mordorintelligence.com` analisi penjualanan mobil bekas pada tahun 2024 diperkirakan mencapai USD 6,41 miliar faktor-faktor seperti peningkatan kualitas mobil bekas, banyaknya ekspatriat, dan harga yang terjangkau untuk mobil bekas diperkirakan akan menjadi faktor pendorong utama pasar. Dan juga kontribusi platform online sangat berpengaruh pada pertumbuhan penjualanan karena sebanyak 98.6% penduduk arab saudi telah menggunakan internet, sehingga dengan adanya platform digital ini mendorong penjual untuk memperlihatkan mobil bekas mereka cukup dengan memberi gambar dan juga informasi kondisi mobil seperti  tipe mobil,merk, tahun produksi, jarak tempuh mobil dll,
# sehingga memudahkan konsumen untuk mengetahui dan berinteraksi dengan penjual. Salah satu platform nya yitu `syarah.com` menyediakan jasa jual beli mobil bekas dengan berbagai macam merk

# %% [markdown]
# ### **Problem Statement**
#
# Salah satu tantangan terbesar bagi pengusaha jual beli mobil bekas baik bebasis offline maupun online adalah masih kurangnya kepercayaan konsumen terhadap mobil bekas sehingga hal tersebut terkadang menyebabkan penjual sulit untuk menentukan harga jual.
#
# Karena mobil bekas sendiri sangat banyak di pasaran dengan harga yang kompetitif namun disamping itu mobil bekas sendiri pasti memiliki kekurangan meski sedikit dan ini sangat menjadi pertimbangan bagi pembeli untuk memilih dan juga bagi penjual ketika menentukan harga
#
# Oleh karena itu perlu adanya sebuah tumpuan bagi penjual untuk menentukan harga yang tetap sehingga pembeli tidak sulit untuk mempertimbangkan mobil tersebut.

# %% [markdown]
# ### **Goals**
#
# Berdasarkan permasalahn tersebut, penjual mobil bekas memerlukan sebuah alat yang dapat **membantu penjual untuk menentukan harga jual yang sesuai untuk semua jenis mobil yang akan mereka jual**. Dengan bantuan pengetahuan mengenai kondisi mobil tersebut seperti tipe mobil, mesin, tahun produksi, jarak tempuh mobil, akan mendapatkan sebuah prediksi harga yang lebih akurat sehingga penjual tidak perlu kesulitan lagi untuk menentukan harga.
#
# Dengan adanya prediksi harga yang lebih akurat membuat konsumen menumbuhkan kepercayaan mereka terhadap penjual karena harga ditentukan berdasarkan kondisi mobil dan juga membantu konsumen yang kurang mengerti mengenai mobil, oleh karena itu apabila konsumen semakin tumbuh kepercayaan nya maka penjualan akan meningkat karena konsumen tidak banyak mempertimbangkan kondisi mobil dan juga terhindar

# %% [markdown]
# ### **Analytic Approach**
#
# Setelah menentukan problem statement kita perlu adanya analisis data untuk menentukan fitur fitur atau bagian bagian mobil mana yang dapat di jadikan jalan untuk membuat alat tersebut.
#
#
# Dan setelahnya kita akan membentuk sebuah model regresi yang akan membantu penjual untuk membuat alat yang dapat memprediksi harga jual mobil dan ini berguna untuk penjual untuk menentukan harga jual yang sesuai dengan kondisi mobil.

# %% [markdown]
# ### **Metric Evaluation**
#
# Pada percobaan machine learning kali ini menggunakan 3 evaluasi metrik yaitu **RMSE, MAE, MAPE**, ketiga metrik tersbut bertujuan untuk melihat nilai eror pada prediksi/ramalan yang telah di buat.
#
# - RMSE atau Root Mean Square Error sebuah metrik untuk mengukur besaran nilai eror semakin kecil nilai nya atau mendekati 0 makan semakin akurat prediksi nya namun jarang sekali niali rmse yang dapat mencapai 0 karena setiap prediksi pasti terdapat kesalahan, metrik ini juga sangat penting karena mempunyai sensitivitas terhadap outliers sehingga memudahkan untuk mengidentifikasi outliers.
#
# - MAE atau mean absolute error, kergunaan nya untuk  perbedaan rata rata dari nilai prediksi dan nilai aktual, memiliki sifat yang sama seperti rmse yaitu semakin kecil nilai nya maka semakin akurat modelnya namun metrik mae ini tidak terlalu sesitif terhadap outliers. Metriks ini juga penting untuk mengur regresi dan distribusi frekuensinya.
#
# - MAPE atau mean percentage error, merupakan metrik untk menghitung rata rata dari selisih persentase anatar nilai prediksi dan aktual sama seperti kedua metrik yang sudah di jelaskan, mape semakin akurat jika nilainya semakin kecil, dna mape juga sangat sensitif terhadap nilai yang sangat kecil, metrik ini sangat cocok untuk permasalahan bisnis terutama untuk prediksi penjualanan atau arus kas serta mudah dipahami karena berbentuk persentase.
#
# Dengan ini ketiga metrik tersebut dianggap cocok untuk permasalahan bisnis yang telah dijelaskan.

# %% [markdown]
# ## **Data Understanding**

# %% [markdown]
# - Dataset merupakan data mobil bekas yang di ambil dari web syarah.com
#
# **Attributes Information**
#
# | **Attribute** | **Data Type** | **Description** |
# | --- | --- | --- |
# | Type | Object | Type of used car |
# | Region | Object | The region in which the used car was offered for sale. |
# | Make | Object | The company name |
# | Gear_Type | Object | Gear type size of used car |
# | Origin | Object | Origin of used car |
# | Options | Object | Options of used car |
# | Year | Integer | Manufacturing year |
# | Engine_Size | float | The engine size of used car |
# | Mileage | Integer | Mileage of used car |
# | Negotiable | Boolean | True if the price is 0, that means it is negotiable. |
# | Price | Integer | Used car price. |
#
#
# <br>

# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('data_saudi_used_cars.csv')
df.head()
# Out:
#           Type          Region        Make  Gear_Type       Origin    Options  \
# 0      Corolla            Abha      Toyota     Manual        Saudi   Standard
# 1        Yukon          Riyadh         GMC  Automatic        Saudi       Full
# 2  Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic       Full
# 3       Optima  Hafar Al-Batin         Kia  Automatic        Saudi  Semi Full
# 4           FJ          Riyadh      Toyota  Automatic        Saudi       Full
#
#    Year  Engine_Size  Mileage  Negotiable   Price
# 0  2013          1.4   421000        True       0
# 1  2014          8.0    80000       False  120000
# 2  2015          5.0   140000       False  260000
# 3  2015          2.4   220000       False   42000
# 4  2020          4.0    49000        True       0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5624 entries, 0 to 5623
# Data columns (total 11 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Type         5624 non-null   object
#  1   Region       5624 non-null   object
#  2   Make         5624 non-null   object
#  3   Gear_Type    5624 non-null   object
#  4   Origin       5624 non-null   object
#  5   Options      5624 non-null   object
#  6   Year         5624 non-null   int64
#  7   Engine_Size  5624 non-null   float64
#  8   Mileage      5624 non-null   int64
#  9   Negotiable   5624 non-null   bool
#  10  Price        5624 non-null   int64
# dtypes: bool(1), float64(1), int64(3), object(6)
# memory usage: 445.0+ KB

# %% [markdown]
# Berdasarkan info yang kita dapat di atas, data set kali ini memiliki lebih dari 5 ribu baris dan 11 kolom sebelum dilakukan cleaning

# %%
pd.set_option('display.max_columns', None) 
list=[]

for col in df.columns:
    list.append([col,df[col].nunique(),df[col].unique(),df[col].dtype])
    
df_model = pd.DataFrame(columns=['dataFeatures','nunique','unique','info'],
                     data=list)
df_model
# Out:
#    dataFeatures  nunique                                             unique  \
# 0          Type      347  [Corolla, Yukon, Range Rover, Optima, FJ, CX3,...
# 1        Region       27  [Abha, Riyadh, Hafar Al-Batin, Aseer, Makkah, ...
# 2          Make       58  [Toyota, GMC, Land Rover, Kia, Mazda, Porsche,...
# 3     Gear_Type        2                                [Manual, Automatic]
# 4        Origin        4               [Saudi, Gulf Arabic, Other, Unknown]
# 5       Options        3                        [Standard, Full, Semi Full]
# 6          Year       50  [2013, 2014, 2015, 2020, 2019, 2012, 2016, 199...
# 7   Engine_Size       71  [1.4, 8.0, 5.0, 2.4, 4.0, 2.0, 4.8, 3.5, 4.6, ...
# 8       Mileage     1716  [421000, 80000, 140000, 220000, 49000, 25000, ...
# 9    Negotiable        2                                      [True, False]
# 10        Price      467  [0, 120000, 260000, 42000, 58000, 85000, 48000...
#
#        info
# 0    object
# 1    object
# 2    object
# ...

# %% [markdown]
# ### **Data Cleaning**

# %% [markdown]
# **1. Missing Value**
#
# Pada tahap pertama ketika sudah mengerti fitur fitur apa saja yang terdapat dalam data maka kita perlu adanya pengecekan terhadap missing value karena hal tersebut kedepannya bakal mempengaruhi terhadap keakuratan analisis dan kebenarannya apabila tidak lakukan treatment yang sesuai.

# %%
list=[]

for col in df.columns:
    list.append([col,df[col].isna().sum()])
    
df_model = pd.DataFrame(columns=['dataFeatures','null'],
                     data=list)
df_model
# Out:
#    dataFeatures  null
# 0          Type     0
# 1        Region     0
# 2          Make     0
# 3     Gear_Type     0
# 4        Origin     0
# 5       Options     0
# 6          Year     0
# 7   Engine_Size     0
# 8       Mileage     0
# 9    Negotiable     0
# 10        Price     0

# %% [markdown]
# setelah dilakukan tahap pengecekan missing value ternyata pada dataset kali ini tidak terdapat missing value dan kita bisa lanjut ke tahap berikutnya.

# %% [markdown]
# **2. Data duplicate**
#
# Kemudian kita perlu melakukan pengecekan pada dataset  adalah cek apakah ada duplikat atau tidak karena data duplikat ini harus kita hapus jika tidak dapat menyebabkan bias pada data baik sedikit maupun banyak jumlah duplikatnya

# %%
df.duplicated().sum()
# Out:
# 4

# %% [markdown]
# terdapat 4 data duplikat maka kita langsung mengahpus data duplikat tersebut.

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# **3. Outliers**
#
# Pada data outliers ada dua cara treatment nya yang pertama kita bisa hapus outliers sedangkan yang kedua kita biarkan outliers nya.
#
# Ouliers dapat di hapus ketika memang data outliers tersebut sangat ekstrim jauh dari persebaran dan dalam jumlah sedikit.
#
# Namun dapat di biarkan juga apabila outliers nya ketika dilihat banyak jumlah nya namun masih terdapat pola dalam datanya atau masih banyak persebarannya dan data tersebut memang perlu adanya.

# %%
# kita bisa melihat outliers 
# menggunakan visualisasi boxplot

plt.figure(figsize=(16,19))

col_num= []
for i in df.columns:
    if (df[i].dtype=='float64')|(df[i].dtype=='int64'):
        col_num.append(i)

for i,col in enumerate(col_num):
    plt.subplot((len(col_num)//5)+(len(col_num)%5),5,i+1)
    sns.boxplot(data=df,x=col)
    plt.title(col)

plt.tight_layout()
plt.show()

# %% [markdown]
# Terlihat sangat jelas outliers ekstrim pada kolom mileage maka kit akan coba cek terlebih dahulu dan akan kita hapus jika memang dapat dihapus.

# %%
mil=df[df['Mileage']>=9000000]
mil
# Out:
#        Type  Region       Make Gear_Type Origin    Options  Year  Engine_Size  \
# 1224  POS24   Aseer   Mercedes    Manual  Other       Full  1983          8.0
# 3403  Optra  Riyadh  Chevrolet    Manual  Other  Semi Full  2009          1.6
#
#        Mileage  Negotiable  Price
# 1224   9999999        True      0
# 3403  20000000       False   9000

# %%
mil=df[df['Mileage']>=9000000].index
df.drop(mil,inplace=True)
df[df['Mileage']>=9000000]
# Out:
# Empty DataFrame
# Columns: [Type, Region, Make, Gear_Type, Origin, Options, Year, Engine_Size, Mileage, Negotiable, Price]
# Index: []

# %% [markdown]
# Kedua data tersebut telah berhasil kita hapus.

# %% [markdown]
# **4. Data anomali**
#
# Lalu kita akan melakukan penghapusan pada data data yang tidak masuk akal atau tidak sesuai dan juga data yang tidak di butuhkan untuk menjadi features

# %%
df.head()
# Out:
#           Type          Region        Make  Gear_Type       Origin    Options  \
# 0      Corolla            Abha      Toyota     Manual        Saudi   Standard
# 1        Yukon          Riyadh         GMC  Automatic        Saudi       Full
# 2  Range Rover          Riyadh  Land Rover  Automatic  Gulf Arabic       Full
# 3       Optima  Hafar Al-Batin         Kia  Automatic        Saudi  Semi Full
# 4           FJ          Riyadh      Toyota  Automatic        Saudi       Full
#
#    Year  Engine_Size  Mileage  Negotiable   Price
# 0  2013          1.4   421000        True       0
# 1  2014          8.0    80000       False  120000
# 2  2015          5.0   140000       False  260000
# 3  2015          2.4   220000       False   42000
# 4  2020          4.0    49000        True       0

# %% [markdown]
# Pada dataset terdapat kolom negotiable, jika true makanya price menjadi 0 hal ini perlu adanya tindakan yang tepat jika berdasarkan domain knowledge feature negotiable ini tidak beerpengaruh untuk penentuan price.
#
# Maka kita akan melakukan penghapusan kolom.

# %%
df.drop(columns='Negotiable',inplace=True)

# %% [markdown]
# Kemudian pada kolom price terdapat nilai 0 juga perlu kita hapus karena normal nya tidak akan ada mobil bekas yang haganya 0.

# %%
df.drop(df[df['Price']==0].index,inplace=True)

# %% [markdown]
# kita coba untuk sort data berdasarkan nilai price terkecil

# %%
df.sort_values(by='Price',ascending=1).head(10)
# Out:
#          Type   Region     Make  Gear_Type Origin    Options  Year  \
# 3131    Yukon   Jubail      GMC  Automatic  Saudi       Full  2019
# 3992      G80   Riyadh  Genesis  Automatic  Other  Semi Full  2018
# 4399    Yaris   Riyadh   Toyota  Automatic  Saudi   Standard  2018
# 5128      Rio     Arar      Kia  Automatic  Saudi   Standard  2019
# 3474    Yaris   Najran   Toyota  Automatic  Saudi   Standard  2019
# 3760        5  Al-Ahsa       MG  Automatic  Saudi   Standard  2020
# 3616  Elantra   Jeddah  Hyundai  Automatic  Saudi   Standard  2019
# 1534    Yukon   Jeddah      GMC  Automatic  Saudi   Standard  2021
# 3892  Corolla     Hail   Toyota  Automatic  Saudi   Standard  2020
# 46    Elantra     Abha  Hyundai  Automatic  Saudi  Semi Full  2020
#
#       Engine_Size  Mileage  Price
# 3131          5.3    50000      1
# 3992          3.8   170000    500
# 4399          1.5   100000    850
# 5128          1.4    55500    884
# 3474          1.6    85000    950
# ...

# %% [markdown]
# Jika dilihat berdasarkan data masih banyak nilai yang kecil untuk harga sebuah mobil bekas, apabila terlalu banyak nilai yang kecil akan menyebabkan nilai MAPE nya overfitting, karena itu kita perlu adanya batasan cut off untuk harga.
#
# Oleh karena itu kita perlu mencari sebuah nilai minimum dari penjualanan mobil bekas di arab saudi jika melihat dari web syarah.com nilai minimum untuk sebuah mobil bekas adalah lebih dari 20 ribu riyal namun nilai tersebut terlalu tinggi maka kita melihat ke sumber lain.

# %%
from matplotlib import image as mpimg
image = mpimg.imread("foto.png")
plt.imshow(image)
plt.show()

# %% [markdown]
# Berdasarkan informasi dari sebuah platform jual beli mobil bekas di saudi arabia ada syarat minimum untuk menjual yaitu sebesar 5 ribu riyal maka kita akan coba menggunakan nilai tersebut sebagai batasan minimum.

# %%
ac=df.query('Price<5000')
ac
# Out:
#                  Type     Region        Make  Gear_Type Origin    Options  \
# 46            Elantra       Abha     Hyundai  Automatic  Saudi  Semi Full
# 65             Malibu       Arar   Chevrolet  Automatic  Saudi   Standard
# 304             Azera     Tabouk     Hyundai  Automatic  Saudi   Standard
# 356            Wingle     Jeddah  Great Wall     Manual  Saudi       Full
# 396                K5      Aseer         Kia  Automatic  Saudi   Standard
# ...               ...        ...         ...        ...    ...        ...
# 5430           Passat       Hail  Volkswagen  Automatic  Saudi  Semi Full
# 5521         Suburban  Al-Medina   Chevrolet  Automatic  Other  Semi Full
# 5523           Tucson     Makkah     Hyundai  Automatic  Saudi  Semi Full
# 5547           Optima     Qassim         Kia  Automatic  Saudi   Standard
# 5609  Land Cruiser 70       Taef      Toyota     Manual  Saudi       Full
#
#       Year  Engine_Size  Mileage  Price
# ...

# %%
ac['Year'].unique()
# Out:
# array([2020, 2021, 2018, 2001, 2017, 2019, 2014, 2016, 2008, 1995, 2015,
#        2003, 1997], dtype=int64)

# %% [markdown]
# Apabila di lihat berdasarkan data pun nilai yang di bawah 5 ribu hanya sedikit dan juga apabila melihat unique dari tahun produksi nya banyak mobil bekas yang diproduksi pada tahun tahun yang belum terlalu jauh dan berdasarkan mileage nya pun masih tergolong belum terlalu tinggi.
#
# Maka kita sekarang hanya akan mengambil data dengan nilai price lebih tinggi atau sama dengan 5 ribu riyal

# %%
df=df.query('Price>=5000')

# %% [markdown]
# ### **Exploratory Data Analysis**

# %% [markdown]
# **Numerik**

# %%
df.describe()
# Out:
#               Year  Engine_Size       Mileage          Price
# count  3755.000000  3755.000000  3.755000e+03    3755.000000
# mean   2014.803196     3.188043  1.385940e+05   79417.952863
# std       5.094043     1.460464  2.013716e+05   72671.122851
# min    1963.000000     1.000000  1.000000e+02    5000.000000
# 25%    2013.000000     2.000000  4.900000e+04   36000.000000
# 50%    2016.000000     2.700000  1.040000e+05   58500.000000
# 75%    2018.000000     4.000000  1.840000e+05   95000.000000
# max    2021.000000     9.000000  4.500000e+06  850000.000000

# %%
df['Mileage'].max()
# Out:
# 4500000

# %% [markdown]
# **Distribusi dari kolom 'price'**

# %%
# Plot distribusi fitur 'price'
plt.figure(figsize=(7, 7))
sns.histplot(df['Price'])
plt.title('Price Distribution', size=15, weight='bold');
plt.show()

# %%
df['Price'].skew()
# Out:
# 3.1280136478014238

# %% [markdown]
# Pada distribusi price didapati bahwa kolom tersebut merupakan right skew

# %%
year10=df.sort_values(by='Year',ascending=False).count()
year10
# Out:
# Type           3755
# Region         3755
# Make           3755
# Gear_Type      3755
# Origin         3755
# Options        3755
# Year           3755
# Engine_Size    3755
# Mileage        3755
# Price          3755
# dtype: int64

# %%
year10=df.groupby('Year')[['Price']].sum().sort_values(by='Price',ascending=False).head(10).reset_index()
year10
# Out:
#    Year     Price
# 0  2016  49308258
# 1  2018  38495000
# 2  2019  37298099
# 3  2020  36742220
# 4  2017  34821400
# 5  2015  30218999
# 6  2014  16867400
# 7  2021  14104800
# 8  2013  12616587
# 9  2012   5918600

# %%
sns.barplot(data=year10,x='Year',y='Price',hue='Year')
plt.title('Top 10 year by price')
# Out:
# Text(0.5, 1.0, 'Top 10 year by price')

# %%
import sweetviz as sv

# %%
laporan=sv.analyze(df)
# Out:
#                                              |          | [  0%]   00:00 -> (? left)

# %%
laporan.show_html('eda_report.html')
# Out:
# Report eda_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df_numeric = df.select_dtypes(include=[float, int])
df_numeric.corr()
# Out:
#                  Year  Engine_Size   Mileage     Price
# Year         1.000000    -0.235084 -0.304428  0.331813
# Engine_Size -0.235084     1.000000  0.086777  0.308876
# Mileage     -0.304428     0.086777  1.000000 -0.198212
# Price        0.331813     0.308876 -0.198212  1.000000

# %%
sns.heatmap(df_numeric.corr(),)
# Out:
# <Axes: >

# %% [markdown]
# Korelasi Year terhadap Price lebih kuat dari features lain dan juga positif ini artinya semakin tinggi tahunnya makan semakin mahal nilai jualnya.

# %%
df['Type'].value_counts().head(10)/len(df)
# Out:
# Type
# Land Cruiser    0.039148
# Accent          0.038881
# Camry           0.038881
# Hilux           0.031158
# Sonata          0.029028
# Taurus          0.027164
# Elantra         0.026365
# Tahoe           0.026365
# Yukon           0.024234
# Corolla         0.021039
# Name: count, dtype: float64

# %% [markdown]
# data diatas merupakan sepuluh tipe mobil bekas teratas berdasarkan persentase nya, mayoritas penduduk arab saudi mengincar mobil bekas dari land cruiser.

# %%
top10=df.groupby('Region')[['Price']].sum().sort_values(by='Price',ascending=False).head(10).reset_index()
top10
# Out:
#       Region      Price
# 0     Riyadh  130951287
# 1     Dammam   69663400
# 2     Jeddah   40524369
# 3     Qassim    8900900
# 4    Al-Ahsa    7120700
# 5  Al-Medina    7073500
# 6     Makkah    6145007
# 7      Aseer    5820500
# 8     Khobar    3682650
# 9       Taef    3109500

# %%
plt.figure(figsize=(10,5))
sns.barplot(data=top10,x='Region',y='Price',hue='Region')
plt.title('Riyadh domination')
# Out:
# Text(0.5, 1.0, 'Riyadh domination')

# %% [markdown]
# wilayah riyadh merupakan wilayah dengan pendapatan dari penjualanan mobil bekas tertinggi dibandingkan wilayah lainnya karena wilayah riyadh sendiri sangat populer dengan dunia otomotif sehingga banyak sekali mobil baru maupun bekas yang terjual.

# %% [markdown]
# ## **Data Preprocessing**

# %%
# Import Library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Data splitting
from sklearn.model_selection import train_test_split

# Library preprocessing
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline

# Library untuk missing values
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

# Library untuk scaling
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler

# Encoding
from sklearn.preprocessing import OneHotEncoder
from category_encoders import OrdinalEncoder, BinaryEncoder

# Cross Validation 
from sklearn.model_selection import cross_val_score, cross_validate,KFold

# Modeling
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import AdaBoostRegressor
from xgboost.sklearn import XGBRegressor
from sklearn.compose import TransformedTargetRegressor
from catboost import CatBoostRegressor
from lightgbm import LGBMRegressor



# Hyperparameter Tuning
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# Metric Evaluation
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error

import ssl
ssl._create_default_https_context = ssl._create_unverified_context

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### **Define X and Y**
#
# Tahap awal untuk melakukan proses machine learning adalah menentukan antara target dan features dan bagian ini sangat penting karena menjadi sebuah tumpuan untuk proses selanjutnya.
#
# Dan kali ini kita akan menjadikan 'price' sebuah target (X) dan kolom selain price akan menjadi features (y).

# %%
X=df.drop(columns='Price')
y=df['Price']

# %% [markdown]
# ### **Train Test Split**
#
# Setelah menentukan target kita perlu membagi data menjadi dua bagian yaitu data training dan data test dengan pola pembagian yang umum digunakan yaitu sebesar 80:20.

# %%
X_train,X_test,y_train,y_test=train_test_split(
    X,
    y,
    test_size=0.2,
    random_state=0
)

# %%
display(len(X_train),len(X_test))
# Out:
# 3004
# 751

# %% [markdown]
# Nah ini adalah jumlah data berdasarkan training dan test nya.

# %% [markdown]
# ### **Encoding**
#
# Proses encoding ini dilakukan untuk merubah tipe data kategorikal/object menjadi angka 0,1 agar dapat di proses oleh machine learning karena machine learning tidak dapat membaca teks sehingg data di buat menjadi numerik agar mempermudah dan mempercepat kerja machine learning.

# %%
df.nunique()
# Out:
# Type            318
# Region           27
# Make             56
# Gear_Type         2
# Origin            4
# Options           3
# Year             41
# Engine_Size      65
# Mileage        1328
# Price           404
# dtype: int64

# %% [markdown]
# - One hot: tipe ini digunakan untuk data yang memiliki unique sedikit seperti `['Gear_type','Origin','Options']`,
#
# - Binary: digunakan pada tipe data yang mempunya unique banyak seperti `['Type','Region','Make']
# `
#
# kemudian pada data numerik akan digunakan **RobustScaler** karena robust sendiri menggunakan median dan IQR sehingga lebih tahan terhadap adanya outliers, seperti yang sudah kita lakukan boxplot terdapat banyak outliers pada data numerik maka lebih baik menggunakan RobustScaler.

# %%
transformer = ColumnTransformer([
    ('onehot',OneHotEncoder(),['Gear_Type','Origin','Options']),
    ('binary',BinaryEncoder(),['Type','Region','Make']),
    ('robust',RobustScaler(),['Engine_Size','Mileage','Year'])
],remainder='passthrough')
transformer
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('onehot', OneHotEncoder(),
#                                  ['Gear_Type', 'Origin', 'Options']),
#                                 ('binary', BinaryEncoder(),
#                                  ['Type', 'Region', 'Make']),
#                                 ('robust', RobustScaler(),
#                                  ['Engine_Size', 'Mileage', 'Year'])])

# %% [markdown]
# ## **Modeling**
#
# Dan di tahap modeling ini kita akan mencoba pengujian pada banyak model, yaitu base model dan ensamble model
# berbasis regresi,
#
# - Linear Regression
# - KNN Regressor
# - Decision Tree Regressor
# - Ridge
# - Lasso
# - Random Forest
# - Ada Boost Regressor
# - Gradient Boost Regressor
# - XGB Regressor
# - catboost
# - lightGBM
#
# Dan untuk metriks nya seperti yang sudah di jelaskan di awal kita akan memakai metrik **RMSE,MAE,MAPE**

# %%
#define algoritma yang di gunakan
lr= LinearRegression()
knn= KNeighborsRegressor()
tree=DecisionTreeRegressor(random_state=42)
rf=RandomForestRegressor(random_state=42)
ada=AdaBoostRegressor(random_state=42)
gb=GradientBoostingRegressor(random_state=42)
ridge=Ridge(random_state=42)
lasso=Lasso(random_state=42)
xgb=XGBRegressor(random_state=42)
cat=CatBoostRegressor(random_state=42,verbose=False)
lgb=LGBMRegressor(random_state=42)

log_lr = TransformedTargetRegressor(lr, func=np.log, inverse_func=np.exp)
log_lasso = TransformedTargetRegressor(lasso, func=np.log, inverse_func=np.exp)
log_ridge = TransformedTargetRegressor(ridge, func=np.log, inverse_func=np.exp)
log_knn = TransformedTargetRegressor(knn, func=np.log, inverse_func=np.exp)
log_dt = TransformedTargetRegressor(tree, func=np.log, inverse_func=np.exp)
log_rf = TransformedTargetRegressor(rf, func=np.log, inverse_func=np.exp)
log_gb = TransformedTargetRegressor(gb, func=np.log, inverse_func=np.exp)
log_xgb = TransformedTargetRegressor(xgb, func=np.log, inverse_func=np.exp)
log_lgbm = TransformedTargetRegressor(lgb, func=np.log, inverse_func=np.exp)
log_ada_boost = TransformedTargetRegressor(ada, func=np.log, inverse_func=np.exp)
log_cat_boost = TransformedTargetRegressor(cat, func=np.log, inverse_func=np.exp)

# membuat list
list_algo=[lr,knn,tree,rf,ridge,lasso,ada,gb,xgb,cat,lgb]
models = [log_lr, log_knn, log_dt, log_rf,log_ridge,log_lasso, log_ada_boost, log_gb,log_xgb,log_cat_boost,log_lgbm]

#define metrik
scorer = ['neg_root_mean_squared_error',
          'neg_mean_absolute_percentage_error',
          'neg_mean_absolute_error']

# membuat list hasil
list_mean_rmse =[]
list_std_rmse = []

list_mean_mae =[]
list_std_mae = []

list_mean_mape =[]
list_std_mape = []



#looping
for algo in models:
    crossval = KFold(n_splits=5, shuffle=True, random_state=42)
    model=algo
# membuat pipeline supaya tidak terjadi information leakage 
# dan untuk menggabungkan preprocessing dengan modeling

    pipe_model=Pipeline([
        ('preprocessing',transformer),
        ('modeling',model)
    ])

    #membuat cross validation
    cv_score=cross_validate(
        estimator=pipe_model,
        X=X_train,
        y=y_train,
        scoring=scorer,
        cv=5,
       
    )

    #scoring
    #scoring 
    list_mean_rmse.append(cv_score['test_neg_root_mean_squared_error'].mean())
    list_std_rmse.append(cv_score['test_neg_root_mean_squared_error'].std())

    list_mean_mae.append(cv_score['test_neg_mean_absolute_error'].mean())
    list_std_mae.append(cv_score['test_neg_mean_absolute_error'].std())

    list_mean_mape.append(cv_score['test_neg_mean_absolute_percentage_error'].mean())
    list_std_mape.append(cv_score['test_neg_mean_absolute_percentage_error'].std())
# Out:
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000475 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 387
# [LightGBM] [Info] Number of data points in the train set: 2403, number of used features: 31
# [LightGBM] [Info] Start training from score 11.007934
# [LightGBM] [Info] Auto-choosing row-wise multi-threading, the overhead of testing was 0.000357 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 391
# [LightGBM] [Info] Number of data points in the train set: 2403, number of used features: 31
# [LightGBM] [Info] Start training from score 10.995661
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000770 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# ...

# %%
df_cv = pd.DataFrame()
#df_cv['algo'] = ['log_lr', 'log_knn', 'log_tree', 'log_rf', 'log_ridge', 'log_lasso', 'log_ada', 'log_gb','log_xgb']
df_cv['name']=list_algo
df_cv['algo'] = models
df_cv['mean_RMSE'] = list_mean_rmse
df_cv['std_RMSE'] = list_std_rmse

df_cv['mean_MAE'] = list_mean_mae
df_cv['std_MAE'] = list_std_mae

df_cv['mean_MAPE'] = list_mean_mape
df_cv['std_MAPE'] = list_std_mape

df_cv.sort_values(by='mean_RMSE',ascending=False)
# Out:
#                                                  name  \
# 9   <catboost.core.CatBoostRegressor object at 0x0...
# 10                     LGBMRegressor(random_state=42)
# 8   XGBRegressor(base_score=None, booster=None, ca...
# 3              RandomForestRegressor(random_state=42)
# 1                               KNeighborsRegressor()
# 7          GradientBoostingRegressor(random_state=42)
# 6                  AdaBoostRegressor(random_state=42)
# 2              DecisionTreeRegressor(random_state=42)
# 0                                  LinearRegression()
# 4                              Ridge(random_state=42)
# 5                              Lasso(random_state=42)
#
#                                                  algo     mean_RMSE  \
# 9   TransformedTargetRegressor(func=<ufunc 'log'>,... -32149.844706
# 10  TransformedTargetRegressor(func=<ufunc 'log'>,... -35916.248946
# 8   TransformedTargetRegressor(func=<ufunc 'log'>,... -36215.395174
# ...

# %%
df_cv.sort_values(by='mean_MAE',ascending=False)
# Out:
#                                                  name  \
# 9   <catboost.core.CatBoostRegressor object at 0x0...
# 10                     LGBMRegressor(random_state=42)
# 8   XGBRegressor(base_score=None, booster=None, ca...
# 3              RandomForestRegressor(random_state=42)
# 1                               KNeighborsRegressor()
# 7          GradientBoostingRegressor(random_state=42)
# 2              DecisionTreeRegressor(random_state=42)
# 4                              Ridge(random_state=42)
# 0                                  LinearRegression()
# 6                  AdaBoostRegressor(random_state=42)
# 5                              Lasso(random_state=42)
#
#                                                  algo     mean_RMSE  \
# 9   TransformedTargetRegressor(func=<ufunc 'log'>,... -32149.844706
# 10  TransformedTargetRegressor(func=<ufunc 'log'>,... -35916.248946
# 8   TransformedTargetRegressor(func=<ufunc 'log'>,... -36215.395174
# ...

# %%
df_cv.sort_values(by='mean_MAPE',ascending=False)
# Out:
#                                                  name  \
# 9   <catboost.core.CatBoostRegressor object at 0x0...
# 10                     LGBMRegressor(random_state=42)
# 8   XGBRegressor(base_score=None, booster=None, ca...
# 3              RandomForestRegressor(random_state=42)
# 7          GradientBoostingRegressor(random_state=42)
# 1                               KNeighborsRegressor()
# 4                              Ridge(random_state=42)
# 0                                  LinearRegression()
# 2              DecisionTreeRegressor(random_state=42)
# 6                  AdaBoostRegressor(random_state=42)
# 5                              Lasso(random_state=42)
#
#                                                  algo     mean_RMSE  \
# 9   TransformedTargetRegressor(func=<ufunc 'log'>,... -32149.844706
# 10  TransformedTargetRegressor(func=<ufunc 'log'>,... -35916.248946
# 8   TransformedTargetRegressor(func=<ufunc 'log'>,... -36215.395174
# ...

# %% [markdown]
# Dari percobaan modeling menggunakan seluruh model / algoritma dan menggunakan metriks  **RMSE,MAE,MAPE** terdapat hasil seperti pada tabel di atas, model **catboost** merupakan model terbaik karena berdasarkan nilai rata rata dari ketiga metriks nya mendapat nilai yang lebih baik dari model lainnya.
#
# Dan dengan ini kita akan langsung melanjutkan hyperparameter tuning untuk model terpilih.

# %% [markdown]
# **Category boosting** atau dikenal dengan **catboost** merupakan sebuah library gradient boosting yang berbasis open source di kembangkan oleh Yandex, catboost beroperasi berdasarkan prinsip gradient boosting, jadi model di bangun secara bertahap, dimulai dengan membuat model yang sederhana secara bertahap kemudian ditingkatkan dengan menambah model baru yang dapat memperbaiki kesalahan pada model sebelumnya.
#
# Selain itu catboost memiliki beberapa keunggulan yaitu:
# - Toleransi terhadap data yang tidak terstruktur
#
# - 'Treatment' terhdap missing value ddengan mengandalkan fitur ditur yan tersedia, sehingga mengurangi kompleksitas proses data.
#
# - Dapat mengatasi overfitting dengan menggunakan kemampuan 'Ordered Boosting', mengoptimalkan batas batas kompleksitas pada setiap iterasi untuk mencegah overfitting
#
# - Kinerja yang tinggi dan kecepatan training yang efisien.

# %%
# Benchmark model terbaik
models = {
    'cat': CatBoostRegressor(random_state=42,verbose=False),
    'log_model' : TransformedTargetRegressor(cat, func=np.log, inverse_func=np.exp)
}

score_rmse = []
score_mae = []
score_mape = []

# Prediksi pada test set
for i in models:

    model = Pipeline([
        ('preprocessing', transformer),
        ('modeling', models[i])
        ])

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    score_rmse.append(np.sqrt(mean_squared_error(y_test, y_pred)))
    score_mae.append(mean_absolute_error(y_test, y_pred))
    score_mape.append(mean_absolute_percentage_error(y_test, y_pred))

score_before_tuning = pd.DataFrame({'RMSE': score_rmse, 'MAE': score_mae, 'MAPE': score_mape}, index=models.keys())
score_before_tuning
# Out:
#                    RMSE           MAE      MAPE
# cat        23444.167857  13514.149623  0.225552
# log_model  22519.761849  12158.800863  0.177073

# %% [markdown]
# ### **Hyperparameter tuning**
#
# Walaupun catboost sudah mendapatkan nilai yang lebih baik dari model lainnya kita tetep perlu melakukan hyperparameter tuning untuk menguji kembali model tersebut dengan harapan apabila sudah di lakukan tahap ini akan menjadi semakin meningkat kualitas modelnya

# %%
hyperparams= {
    'modeling__regressor__iterations': [500,1000,2000], 
    'modeling__regressor__learning_rate': [0.01, 0.05, 0.1, 0.2, 0.3],
    'modeling__regressor__subsample': [0.7,0.8,0.9,1.0],
    'modeling__regressor__l2_leaf_reg': range(1,11),
    'modeling__regressor__border_count':range(32,65),
    'modeling__regressor__early_stopping_rounds':[100],
    'modeling__regressor__max_depth':range(1,11)}
#metrik
scorer = ['neg_root_mean_squared_error',
          'neg_mean_absolute_percentage_error',
          'neg_mean_absolute_error']

# Benchmark model dengan hyperparameter tuning
#model= TransformedTargetRegressor(cat, func=np.log, inverse_func=np.exp)
# Model definition
model = CatBoostRegressor(random_state=42, verbose=False)

# Apply TransformedTargetRegressor
log_model = TransformedTargetRegressor(model, func=np.log, inverse_func=np.exp)

# Preprocessing and pipeline
# Membuat algorithm chains
pipe_model=Pipeline([
    ('preprocessing',transformer),
    ('modeling',log_model)
])
crossval = KFold(n_splits=5, shuffle=True, random_state=42)
#define gridsearch
random=RandomizedSearchCV(
    estimator=pipe_model,
    cv=crossval,
    scoring=scorer,
    n_iter=250,
    n_jobs=-1,
    refit='neg_mean_absolute_percentage_error',
    param_distributions=hyperparams
)
random
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('onehot',
#                                                                                OneHotEncoder(),
#                                                                                ['Gear_Type',
#                                                                                 'Origin',
#                                                                                 'Options']),
#                                                                               ('binary',
#                                                                                BinaryEncoder(),
#                                                                                ['Type',
# ...

# %%
random.fit(X_train,y_train)
# Out:
# RandomizedSearchCV(cv=KFold(n_splits=5, random_state=42, shuffle=True),
#                    estimator=Pipeline(steps=[('preprocessing',
#                                               ColumnTransformer(remainder='passthrough',
#                                                                 transformers=[('onehot',
#                                                                                OneHotEncoder(),
#                                                                                ['Gear_Type',
#                                                                                 'Origin',
#                                                                                 'Options']),
#                                                                               ('binary',
#                                                                                BinaryEncoder(),
#                                                                                ['Type',
# ...

# %%
# Melihat hasil tuning dalam bentuk dataframe. Diurutkan berdasarkan RMSE, MAE & MAPE
pd.DataFrame(random.cv_results_).sort_values(by=['rank_test_neg_root_mean_squared_error', 'rank_test_neg_mean_absolute_error', 'rank_test_neg_mean_absolute_percentage_error']).head()
# Out:
#      mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 208       8.006471      0.523715         0.059572        0.011096
# 137       9.120510      0.210503         0.092164        0.016589
# 193      22.948181      1.175358         0.056470        0.002869
# 123      29.064455      5.279665         0.070174        0.015113
# 39       11.009725      0.472934         0.058789        0.008458
#
#     param_modeling__regressor__subsample param_modeling__regressor__max_depth  \
# 208                                  0.7                                    5
# 137                                  0.7                                    6
# 193                                  0.9                                    6
# 123                                  0.8                                    6
# 39                                   1.0                                    6
#
#     param_modeling__regressor__learning_rate  \
# 208                                      0.1
# ...

# %%
# Cek skor dan params terbaik
print('catboost')
print('Best_score:', random.best_score_)
print('Best_params:', random.best_params_)
# Out:
# catboost
# Best_score: -0.19255999580563282
# Best_params: {'modeling__regressor__subsample': 0.9, 'modeling__regressor__max_depth': 7, 'modeling__regressor__learning_rate': 0.05, 'modeling__regressor__l2_leaf_reg': 1, 'modeling__regressor__iterations': 1000, 'modeling__regressor__early_stopping_rounds': 100, 'modeling__regressor__border_count': 49}

# %% [markdown]
# **Predict to test set with the tuned model**

# %%
# Model XGBoost
model = {'cat': CatBoostRegressor(random_state=42),
         'log_model' : TransformedTargetRegressor(model, func=np.log, inverse_func=np.exp)}

# Define model terhadap estimator terbaik
cat_tuning = random.best_estimator_

# Fitting model
cat_tuning.fit(X_train, y_train)

# Predict test set
y_pred_cat_tuning = cat_tuning.predict(X_test)

# Simpan nilai metrics RMSE, MAE & MAPE setelah tuning
rmse_cat_tuning = np.sqrt(mean_squared_error(y_test, y_pred_cat_tuning))
mae_cat_tuning = mean_absolute_error(y_test, y_pred_cat_tuning)
mape_cat_tuning = mean_absolute_percentage_error(y_test, y_pred_cat_tuning)

score_after_tuning = pd.DataFrame({'RMSE': rmse_cat_tuning, 'MAE': mae_cat_tuning, 'MAPE': mape_cat_tuning}, index=model.keys())
score_after_tuning
# Out:
#                    RMSE          MAE      MAPE
# cat        21643.560545  11827.46622  0.177742
# log_model  21643.560545  11827.46622  0.177742

# %% [markdown]
# ### **Performance Comparison**

# %%
# Sebelum hyperparameter tuning
pd.DataFrame(score_before_tuning.loc['cat']).T
# Out:
#              RMSE           MAE      MAPE
# cat  23444.167857  13514.149623  0.225552

# %%
# Setelah hyperparameter tuning
score_after_tuning
# Out:
#                    RMSE          MAE      MAPE
# cat        21643.560545  11827.46622  0.177742
# log_model  21643.560545  11827.46622  0.177742

# %%
random.best_params_
# Out:
# {'modeling__regressor__subsample': 0.9,
#  'modeling__regressor__max_depth': 7,
#  'modeling__regressor__learning_rate': 0.05,
#  'modeling__regressor__l2_leaf_reg': 1,
#  'modeling__regressor__iterations': 1000,
#  'modeling__regressor__early_stopping_rounds': 100,
#  'modeling__regressor__border_count': 49}

# %% [markdown]
# Dan setelah dilakukan tindakan hyperparameter tuning, model mengalami peningkatan performa yang cukup bagus
# terutama untuk nilai MAPE nya. Dengan ini membuktikan bahwa hyperparameter tuning cukup berguna apabila ingin meningkatkan performa.

# %%
# Menghitung residual
residual = y_test - y_pred_cat_tuning

# Visualisasi residual
plt.figure(figsize=(10,5))
plt.scatter(y_pred_cat_tuning, residual)
plt.axhline(0, color='red', linestyle='--')
plt.title('Residual vs Prediksi')
plt.xlabel('Prediksi')
plt.ylabel('Residual')
plt.show()

# %% [markdown]
# Residuals Sebagian Besar Dekat dengan Garis Nol:
#
# nilai residual sebagian besar sudah banyak mendekati garis nol, menunjukan bahwa model cukup baik untuk memprediksi harga mobil bekas, dan bagus dikisaran harga minimun hingga 100k, namun untuk harga yang lebih tinggi dari itu residual nya mulai tersebar ini menunjukan model masih perlu ditingkatkan untuk prediksi harga yang lebih tinggi.
#
# Dan tidak ada pola yang jelas dalam grafik plot redisual sehingga dapat dikatakan model ini tidak bias.

# %% [markdown]
# ## **Feature Importance**

# %%
tes=random.best_estimator_
tes.fit(X_train,y_train)
tes.get_feature_names_out
# Out:
# <bound method Pipeline.get_feature_names_out of Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehot', OneHotEncoder(),
#                                                   ['Gear_Type', 'Origin',
#                                                    'Options']),
#                                                  ('binary', BinaryEncoder(),
#                                                   ['Type', 'Region', 'Make']),
#                                                  ('robust', RobustScaler(),
#                                                   ['Engine_Size', 'Mileage',
#                                                    'Year'])])),
#                 ('modeling',
#                  TransformedTargetRegressor(func=<ufunc 'log'>,
#                                             inverse_func=<ufunc 'exp'>,
# ...

# %%
model_baseline = tes.named_steps['modeling'].regressor_


if hasattr(model_baseline, 'feature_importances_'):
    feature_importances = model_baseline.feature_importances_
else:
    print("Model dasar tidak mendukung feature_importances_")


if hasattr(model_baseline, 'feature_importances_'):
    
    features = tes.named_steps['preprocessing'].get_feature_names_out()
    
  
    feature_imp_df = pd.DataFrame({
        'Feature': features,
        'Importance': feature_importances
    }).sort_values(by='Importance', ascending=False)
    
    print(feature_imp_df)
else:
    print("Tidak ada feature_importances_ yang dapat diakses.")
# Out:
#                         Feature  Importance
# 31                 robust__Year   25.812085
# 29          robust__Engine_Size   21.589194
# 30              robust__Mileage    7.206585
# 28               binary__Make_5    6.036679
# 6          onehot__Options_Full    5.383041
# 27               binary__Make_4    4.778603
# 25               binary__Make_2    4.389085
# 24               binary__Make_1    3.601202
# 26               binary__Make_3    2.630861
# 12               binary__Type_3    1.932737
# 16               binary__Type_7    1.878725
# 14               binary__Type_5    1.665058
# 15               binary__Type_6    1.597934
# 13               binary__Type_4    1.478715
# 17               binary__Type_8    1.456700
# 11               binary__Type_2    1.242963
# 10               binary__Type_1    0.956283
# 8      onehot__Options_Standard    0.830270
# 4          onehot__Origin_Saudi    0.721762
# 23               binary__Make_0    0.715466
# ...

# %%
sns.barplot(data = feature_imp_df,x = 'Importance', y = 'Feature',)
# Out:
# <Axes: xlabel='Importance', ylabel='Feature'>

# %% [markdown]
# - robust_year
# kolom ini berdasarkan grafik sangat berpengaruh terhadap model karena memang tahun senidir merupakan kondisi penting untuk penentuan harga mobil bekas

# %% [markdown]
# ## **Conclusion**

# %% [markdown]
# Berdasarkan pemodelan yang sudah kita lakukan menggunakan tiga evaluasi metrik **RMSE MAE DAN MAPE** dengan refit metrik nya MAPE didapati setelah hyperparameter tuning bahwa nilai error nya adalah 17%, dapat disimpulkan bahwa ketika nanti model ini digunakan pada data dengan rentang price yang sama, maka perkiraan harganya rata rata meleset kurang lebih 17% dari keakuratan harga aslinya. Namun apabila dilihat dari nilai error nya dibawah 19% dapat disimpulkan model ini cukup bagus untuk dijadikan alat prediksi.
#
# Kemudian model diperkuat dengan grafik dari redisual yang ternyata model ini bagus dan cenderung tidak bias karena rata rata niali mendekati garis nol ,
#
# Selain itu, adanya limitasi pada rentang harga juga dapat membantu dalam mengurangi error prediksi, karena model lebih fokus pada data yang memiliki distribusi serupa, mengurangi kemungkinan prediksi yang jauh meleset.
#
# Namun tetap model ini masih perlu adanya peningkatan, karena keterbatasan feature dan juga jumlah data membuat model ini belum maksimal

# %% [markdown]
# ## **Recommendations**
#
# Beberapa rekomendasi yang dapat membantu meningkatkan performa model:
#
# 1. Perlu adanya petimbangan penambahan feature feature yang sesuai dengan kondisi mobil contohnya seperti apakah ada kerusakan pada body mobil, kondisi mesin, apakah ada variasi pada mobilnya, dll. Dengan ini membantu model untuk lebih memahami mengenai data sehingga dapat meningkatkan keakuratan model.
#
# 2. Limitasi harga (target) berdasarkan pembelajaran model yang telah kita lakukan dengan menggunakan limitasi harga sangat berpengaruh terhadap penurunan nilai error nya oleh karena itu dapat dilakukan limitasi harga yang lebih tinggi diharapkan dengan itu model bisa menjadi lebih baik lagi.
#
# 3. Jika diperlukan ada pembagian antara harga yang tinggi dan rendah dengan limitasi yang akan ditentukan oleh masing masing pihak dengan ini akan lebih tergambar untuk pemilihan model dan juga evaluasi metrik yang akan digunakan.
#
# 4. Karena syarah.com merupakan platform berbasis online maka semestinya terdapat data mengenai mobil yang banyak menjadi favorit pengguna dan juga mobil dengan engangement terbanyak hal ini bisa menjadi sebuah tambahan untuk menjadi feature dengan hal tersebut dapat diprediksi estimasi untk harga mobil yang mempunya demand lebih tinggi di bandingkan mobil lainnya.

# %% [markdown]
# ## **Save Model**

# %%
import pickle

# %%
#best model
cat_tuning=random.best_estimator_
cat_tuning

#fit
cat_tuning.fit(X,y)

#save with pickle
pickle.dump(cat_tuning,open('model_catboost.sav','wb'))

# %%
# load model
model_loaded = pickle.load(open('model_catboost.sav','rb'))
model_loaded
# Out:
# Pipeline(steps=[('preprocessing',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('onehot', OneHotEncoder(),
#                                                   ['Gear_Type', 'Origin',
#                                                    'Options']),
#                                                  ('binary', BinaryEncoder(),
#                                                   ['Type', 'Region', 'Make']),
#                                                  ('robust', RobustScaler(),
#                                                   ['Engine_Size', 'Mileage',
#                                                    'Year'])])),
#                 ('modeling',
#                  TransformedTargetRegressor(func=<ufunc 'log'>,
#                                             inverse_func=<ufunc 'exp'>,
#                                             regressor=<catboost.core.CatBoostRegressor object at 0x000001714B0BF0B0>))])

# %%
sample_predict = pd.DataFrame({
    'Type':['Fj'],
    'Region':['Al-Medina'],
    'Make':['Toyota'],
    'Gear_Type':['Automatic'],
    'Origin':['Saudi'],
    'Options':['Semi Full'],
    'Year':[2019],
    'Engine_Size':[2.5],
    'Mileage':[3000]
})

sample_predict
# Out:
#   Type     Region    Make  Gear_Type Origin    Options  Year  Engine_Size  \
# 0   Fj  Al-Medina  Toyota  Automatic  Saudi  Semi Full  2019          2.5
#
#    Mileage
# 0     3000

# %%
model_loaded.predict(sample_predict)
# Out:
# array([115329.74584055])
